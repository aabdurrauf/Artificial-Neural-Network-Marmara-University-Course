# %%
import tensorflow as tf
import keras
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense,Flatten
from keras import layers

# %%
(x_train,y_train),(x_test,y_test)=keras.datasets.fashion_mnist.load_data()

# %%
(x_train,y_train),(x_test,y_test)=keras.datasets.cifar10.load_data()

# %%
from skimage.io import imshow
import random
q = random.randint(0, len(x_train))
print(q)
imshow(x_train[q])
print(y_train[q])
plt.show()
# Out:
# 9446
# [2]

# %%
print(np.shape(x_train))
X=np.concatenate((x_train,x_test))
Y=np.concatenate((y_train,y_test))
print(np.shape(X))
print(np.shape(Y))
Y = keras.utils.to_categorical(Y, 10)
# Out:
# (50000, 32, 32, 3)
# (60000, 32, 32, 3)
# (60000, 1)

# %%
from sklearn.model_selection import KFold

# %%
kfold = KFold(n_splits=5, shuffle=True)
scores=[]
for train, test in kfold.split(X, Y):
  print(np.shape(train))
  print(np.shape(test))
  model = keras.Sequential(
    [
        keras.Input(shape=np.shape(X[0])),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Flatten(),
        layers.Dropout(0.2),
        layers.Dense(10, activation="softmax"),
    ]
  )

  model.summary()
  batch_size = 128
  epochs = 2

  opt = keras.optimizers.RMSprop(learning_rate=0.001)
  model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

  model.fit(X[train], Y[train], batch_size=batch_size, epochs=epochs)
  score = model.evaluate(X[test], Y[test], verbose=0)
  print("Test loss:", score[0])
  print("Test accuracy:", score[1])
  scores.append(score[1])
print(scores)
# Out:
# (48000,)
# (12000,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32, 32, 32)        128
#
#  dense_1 (Dense)             (None, 32, 32, 32)        1056
#
#  dense_2 (Dense)             (None, 32, 32, 32)        1056
#
#  dense_3 (Dense)             (None, 32, 32, 32)        1056
#
#  dense_4 (Dense)             (None, 32, 32, 32)        1056
#
#  dense_5 (Dense)             (None, 32, 32, 32)        1056
#
#  dense_6 (Dense)             (None, 32, 32, 32)        1056
#
#  dense_7 (Dense)             (None, 32, 32, 32)        1056
#
#  dense_8 (Dense)             (None, 32, 32, 32)        1056
#
#  dense_9 (Dense)             (None, 32, 32, 32)        1056
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dropout (Dropout)           (None, 32768)             0
#
#  dense_10 (Dense)            (None, 10)                327690
#
# =================================================================
# Total params: 337322 (1.29 MB)
# Trainable params: 337322 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 134s 354ms/step - loss: 1.9231 - accuracy: 0.3511
# Epoch 2/2
# 375/375 [==============================] - 128s 342ms/step - loss: 1.5486 - accuracy: 0.4586
# Test loss: 1.5108963251113892
# Test accuracy: 0.4722500145435333
# (48000,)
# (12000,)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 32, 32, 32)        128
#
#  dense_12 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_13 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_14 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_15 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_16 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_17 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_18 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_19 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_20 (Dense)            (None, 32, 32, 32)        1056
#
#  flatten_1 (Flatten)         (None, 32768)             0
#
#  dropout_1 (Dropout)         (None, 32768)             0
#
#  dense_21 (Dense)            (None, 10)                327690
#
# =================================================================
# Total params: 337322 (1.29 MB)
# Trainable params: 337322 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 129s 340ms/step - loss: 2.2334 - accuracy: 0.3434
# Epoch 2/2
# 375/375 [==============================] - 125s 332ms/step - loss: 1.5479 - accuracy: 0.4571
# Test loss: 1.5004130601882935
# Test accuracy: 0.4749999940395355
# (48000,)
# (12000,)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_22 (Dense)            (None, 32, 32, 32)        128
#
#  dense_23 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_24 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_25 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_26 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_27 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_28 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_29 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_30 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_31 (Dense)            (None, 32, 32, 32)        1056
#
#  flatten_2 (Flatten)         (None, 32768)             0
#
#  dropout_2 (Dropout)         (None, 32768)             0
#
#  dense_32 (Dense)            (None, 10)                327690
#
# =================================================================
# Total params: 337322 (1.29 MB)
# Trainable params: 337322 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 127s 336ms/step - loss: 2.1349 - accuracy: 0.3360
# Epoch 2/2
# 375/375 [==============================] - 124s 331ms/step - loss: 1.5464 - accuracy: 0.4575
# Test loss: 1.5197107791900635
# Test accuracy: 0.4637500047683716
# (48000,)
# (12000,)
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_33 (Dense)            (None, 32, 32, 32)        128
#
#  dense_34 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_35 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_36 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_37 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_38 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_39 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_40 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_41 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_42 (Dense)            (None, 32, 32, 32)        1056
#
#  flatten_3 (Flatten)         (None, 32768)             0
#
#  dropout_3 (Dropout)         (None, 32768)             0
#
#  dense_43 (Dense)            (None, 10)                327690
#
# =================================================================
# Total params: 337322 (1.29 MB)
# Trainable params: 337322 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 128s 337ms/step - loss: 1.8711 - accuracy: 0.3591
# Epoch 2/2
# 375/375 [==============================] - 125s 333ms/step - loss: 1.5455 - accuracy: 0.4561
# Test loss: 1.4866154193878174
# Test accuracy: 0.4794166684150696
# (48000,)
# (12000,)
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_44 (Dense)            (None, 32, 32, 32)        128
#
#  dense_45 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_46 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_47 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_48 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_49 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_50 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_51 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_52 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_53 (Dense)            (None, 32, 32, 32)        1056
#
#  flatten_4 (Flatten)         (None, 32768)             0
#
#  dropout_4 (Dropout)         (None, 32768)             0
#
#  dense_54 (Dense)            (None, 10)                327690
#
# =================================================================
# Total params: 337322 (1.29 MB)
# Trainable params: 337322 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 127s 334ms/step - loss: 2.5536 - accuracy: 0.3225
# Epoch 2/2
# 375/375 [==============================] - 124s 331ms/step - loss: 1.5796 - accuracy: 0.4470
# Test loss: 1.5083568096160889
# Test accuracy: 0.46191665530204773
# [0.4722500145435333, 0.4749999940395355, 0.4637500047683716, 0.4794166684150696, 0.46191665530204773]

# %%
kfold = KFold(n_splits=5, shuffle=True)
scores=[]
for train, test in kfold.split(X, Y):
  print(np.shape(train))
  print(np.shape(test))
  model = keras.Sequential(
    [
        keras.Input(shape=np.shape(X[0])),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Dense(32, activation="relu"),
        layers.Flatten(),
        layers.Dropout(0.2),
        layers.Dense(10, activation="softmax"),
    ]
  )

  model.summary()
  batch_size = 128
  epochs = 2

  opt = keras.optimizers.RMSprop(learning_rate=0.0001)
  model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

  model.fit(X[train], Y[train], batch_size=batch_size, epochs=epochs)
  score = model.evaluate(X[test], Y[test], verbose=0)
  print("Test loss:", score[0])
  print("Test accuracy:", score[1])
  scores.append(score[1])
print(scores)
# Out:
# (48000,)
# (12000,)
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_55 (Dense)            (None, 32, 32, 32)        128
#
#  dense_56 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_57 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_58 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_59 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_60 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_61 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_62 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_63 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_64 (Dense)            (None, 32, 32, 32)        1056
#
#  flatten_5 (Flatten)         (None, 32768)             0
#
#  dropout_5 (Dropout)         (None, 32768)             0
#
#  dense_65 (Dense)            (None, 10)                327690
#
# =================================================================
# Total params: 337322 (1.29 MB)
# Trainable params: 337322 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 128s 338ms/step - loss: 2.0525 - accuracy: 0.3132
# Epoch 2/2
# 375/375 [==============================] - 127s 339ms/step - loss: 1.6157 - accuracy: 0.4293
# Test loss: 1.5827693939208984
# Test accuracy: 0.44583332538604736
# (48000,)
# (12000,)
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_66 (Dense)            (None, 32, 32, 32)        128
#
#  dense_67 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_68 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_69 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_70 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_71 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_72 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_73 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_74 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_75 (Dense)            (None, 32, 32, 32)        1056
#
#  flatten_6 (Flatten)         (None, 32768)             0
#
#  dropout_6 (Dropout)         (None, 32768)             0
#
#  dense_76 (Dense)            (None, 10)                327690
#
# =================================================================
# Total params: 337322 (1.29 MB)
# Trainable params: 337322 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 130s 343ms/step - loss: 1.7376 - accuracy: 0.3805
# Epoch 2/2
# 375/375 [==============================] - 128s 342ms/step - loss: 1.5783 - accuracy: 0.4471
# Test loss: 1.5880264043807983
# Test accuracy: 0.4440833330154419
# (48000,)
# (12000,)
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_77 (Dense)            (None, 32, 32, 32)        128
#
#  dense_78 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_79 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_80 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_81 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_82 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_83 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_84 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_85 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_86 (Dense)            (None, 32, 32, 32)        1056
#
#  flatten_7 (Flatten)         (None, 32768)             0
#
#  dropout_7 (Dropout)         (None, 32768)             0
#
#  dense_87 (Dense)            (None, 10)                327690
#
# =================================================================
# Total params: 337322 (1.29 MB)
# Trainable params: 337322 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 130s 343ms/step - loss: 1.8870 - accuracy: 0.3408
# Epoch 2/2
# 375/375 [==============================] - 129s 343ms/step - loss: 1.6091 - accuracy: 0.4324
# Test loss: 1.575308084487915
# Test accuracy: 0.4442499876022339
# (48000,)
# (12000,)
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_88 (Dense)            (None, 32, 32, 32)        128
#
#  dense_89 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_90 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_91 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_92 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_93 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_94 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_95 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_96 (Dense)            (None, 32, 32, 32)        1056
#
#  dense_97 (Dense)            (None, 32, 32, 32)        1056
#
#  flatten_8 (Flatten)         (None, 32768)             0
#
#  dropout_8 (Dropout)         (None, 32768)             0
#
#  dense_98 (Dense)            (None, 10)                327690
#
# =================================================================
# Total params: 337322 (1.29 MB)
# Trainable params: 337322 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 125s 331ms/step - loss: 2.0613 - accuracy: 0.3175
# Epoch 2/2
# 375/375 [==============================] - 124s 330ms/step - loss: 1.6209 - accuracy: 0.4269
# Test loss: 1.603201985359192
# Test accuracy: 0.4259999990463257
# (48000,)
# (12000,)
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_99 (Dense)            (None, 32, 32, 32)        128
#
#  dense_100 (Dense)           (None, 32, 32, 32)        1056
#
#  dense_101 (Dense)           (None, 32, 32, 32)        1056
#
#  dense_102 (Dense)           (None, 32, 32, 32)        1056
#
#  dense_103 (Dense)           (None, 32, 32, 32)        1056
#
#  dense_104 (Dense)           (None, 32, 32, 32)        1056
#
#  dense_105 (Dense)           (None, 32, 32, 32)        1056
#
#  dense_106 (Dense)           (None, 32, 32, 32)        1056
#
#  dense_107 (Dense)           (None, 32, 32, 32)        1056
#
#  dense_108 (Dense)           (None, 32, 32, 32)        1056
#
#  flatten_9 (Flatten)         (None, 32768)             0
#
#  dropout_9 (Dropout)         (None, 32768)             0
#
#  dense_109 (Dense)           (None, 10)                327690
#
# =================================================================
# Total params: 337322 (1.29 MB)
# Trainable params: 337322 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 125s 327ms/step - loss: 1.8510 - accuracy: 0.3420
# Epoch 2/2
# 375/375 [==============================] - 123s 329ms/step - loss: 1.6139 - accuracy: 0.4289
# Test loss: 1.5717880725860596
# Test accuracy: 0.44983333349227905
# [0.44583332538604736, 0.4440833330154419, 0.4442499876022339, 0.4259999990463257, 0.44983333349227905]

# %%
kfold = KFold(n_splits=5, shuffle=True)
scores=[]
for train, test in kfold.split(X, Y):
  print(np.shape(train))
  print(np.shape(test))
  model = keras.Sequential(
    [
        keras.Input(shape=np.shape(X[0])),
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        # layers.Dense(64, activation="relu"),
        # layers.Dense(64, activation="relu"),
        # layers.Dense(64, activation="relu"),
        # layers.Dense(64, activation="relu"),
        # layers.Dense(64, activation="relu"),
        layers.Flatten(),
        layers.Dropout(0.2),
        layers.Dense(10, activation="softmax"),
    ]
  )

  model.summary()
  batch_size = 128
  epochs = 2

  opt = keras.optimizers.RMSprop(learning_rate=0.001)
  model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

  model.fit(X[train], Y[train], batch_size=batch_size, epochs=epochs)
  score = model.evaluate(X[test], Y[test], verbose=0)
  print("Test loss:", score[0])
  print("Test accuracy:", score[1])
  scores.append(score[1])
print(scores)
# Out:
# (48000,)
# (12000,)
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_230 (Dense)           (None, 32, 32, 64)        256
#
#  dense_231 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_232 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_233 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_234 (Dense)           (None, 32, 32, 64)        4160
#
#  flatten_30 (Flatten)        (None, 65536)             0
#
#  dropout_30 (Dropout)        (None, 65536)             0
#
#  dense_235 (Dense)           (None, 10)                655370
#
# =================================================================
# Total params: 672266 (2.56 MB)
# Trainable params: 672266 (2.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 215s 572ms/step - loss: 5.5236 - accuracy: 0.2286
# Epoch 2/2
# 375/375 [==============================] - 213s 569ms/step - loss: 2.2324 - accuracy: 0.2652
# Test loss: 2.1599018573760986
# Test accuracy: 0.27175000309944153
# (48000,)
# (12000,)
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_236 (Dense)           (None, 32, 32, 64)        256
#
#  dense_237 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_238 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_239 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_240 (Dense)           (None, 32, 32, 64)        4160
#
#  flatten_31 (Flatten)        (None, 65536)             0
#
#  dropout_31 (Dropout)        (None, 65536)             0
#
#  dense_241 (Dense)           (None, 10)                655370
#
# =================================================================
# Total params: 672266 (2.56 MB)
# Trainable params: 672266 (2.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 215s 572ms/step - loss: 3.9920 - accuracy: 0.1773
# Epoch 2/2
# 375/375 [==============================] - 215s 575ms/step - loss: 2.4699 - accuracy: 0.1822
# Test loss: 2.1883816719055176
# Test accuracy: 0.19875000417232513
# (48000,)
# (12000,)
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_242 (Dense)           (None, 32, 32, 64)        256
#
#  dense_243 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_244 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_245 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_246 (Dense)           (None, 32, 32, 64)        4160
#
#  flatten_32 (Flatten)        (None, 65536)             0
#
#  dropout_32 (Dropout)        (None, 65536)             0
#
#  dense_247 (Dense)           (None, 10)                655370
#
# =================================================================
# Total params: 672266 (2.56 MB)
# Trainable params: 672266 (2.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 215s 572ms/step - loss: 4.7904 - accuracy: 0.1972
# Epoch 2/2
# 375/375 [==============================] - 214s 571ms/step - loss: 2.2892 - accuracy: 0.2109
# Test loss: 2.136577606201172
# Test accuracy: 0.23141667246818542
# (48000,)
# (12000,)
# Model: "sequential_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_248 (Dense)           (None, 32, 32, 64)        256
#
#  dense_249 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_250 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_251 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_252 (Dense)           (None, 32, 32, 64)        4160
#
#  flatten_33 (Flatten)        (None, 65536)             0
#
#  dropout_33 (Dropout)        (None, 65536)             0
#
#  dense_253 (Dense)           (None, 10)                655370
#
# =================================================================
# Total params: 672266 (2.56 MB)
# Trainable params: 672266 (2.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 213s 567ms/step - loss: 5.1554 - accuracy: 0.2212
# Epoch 2/2
# 375/375 [==============================] - 215s 573ms/step - loss: 2.2911 - accuracy: 0.2135
# Test loss: 2.2272188663482666
# Test accuracy: 0.15925000607967377
# (48000,)
# (12000,)
# Model: "sequential_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_254 (Dense)           (None, 32, 32, 64)        256
#
#  dense_255 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_256 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_257 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_258 (Dense)           (None, 32, 32, 64)        4160
#
#  flatten_34 (Flatten)        (None, 65536)             0
#
#  dropout_34 (Dropout)        (None, 65536)             0
#
#  dense_259 (Dense)           (None, 10)                655370
#
# =================================================================
# Total params: 672266 (2.56 MB)
# Trainable params: 672266 (2.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 214s 570ms/step - loss: 4.3743 - accuracy: 0.2600
# Epoch 2/2
# 375/375 [==============================] - 214s 570ms/step - loss: 1.8331 - accuracy: 0.3658
# Test loss: 1.8107260465621948
# Test accuracy: 0.3890833258628845
# [0.27175000309944153, 0.19875000417232513, 0.23141667246818542, 0.15925000607967377, 0.3890833258628845]

# %%
kfold = KFold(n_splits=5, shuffle=True)
scores=[]
for train, test in kfold.split(X, Y):
  print(np.shape(train))
  print(np.shape(test))
  model = keras.Sequential(
    [
        keras.Input(shape=np.shape(X[0])),
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        layers.Dense(64, activation="relu"),
        # layers.Dense(64, activation="relu"),
        # layers.Dense(64, activation="relu"),
        # layers.Dense(64, activation="relu"),
        # layers.Dense(64, activation="relu"),
        # layers.Dense(64, activation="relu"),
        layers.Flatten(),
        layers.Dropout(0.2),
        layers.Dense(10, activation="softmax"),
    ]
  )

  model.summary()
  batch_size = 128
  epochs = 2

  opt = keras.optimizers.RMSprop(learning_rate=0.0001)
  model.compile(loss="categorical_crossentropy", optimizer=opt, metrics=["accuracy"])

  model.fit(X[train], Y[train], batch_size=batch_size, epochs=epochs)
  score = model.evaluate(X[test], Y[test], verbose=0)
  print("Test loss:", score[0])
  print("Test accuracy:", score[1])
  scores.append(score[1])
print(scores)
# Out:
# (48000,)
# (12000,)
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_200 (Dense)           (None, 32, 32, 64)        256
#
#  dense_201 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_202 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_203 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_204 (Dense)           (None, 32, 32, 64)        4160
#
#  flatten_25 (Flatten)        (None, 65536)             0
#
#  dropout_25 (Dropout)        (None, 65536)             0
#
#  dense_205 (Dense)           (None, 10)                655370
#
# =================================================================
# Total params: 672266 (2.56 MB)
# Trainable params: 672266 (2.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 212s 565ms/step - loss: 4.7421 - accuracy: 0.2952
# Epoch 2/2
# 375/375 [==============================] - 210s 560ms/step - loss: 1.6231 - accuracy: 0.4311
# Test loss: 1.5856114625930786
# Test accuracy: 0.44350001215934753
# (48000,)
# (12000,)
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_206 (Dense)           (None, 32, 32, 64)        256
#
#  dense_207 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_208 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_209 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_210 (Dense)           (None, 32, 32, 64)        4160
#
#  flatten_26 (Flatten)        (None, 65536)             0
#
#  dropout_26 (Dropout)        (None, 65536)             0
#
#  dense_211 (Dense)           (None, 10)                655370
#
# =================================================================
# Total params: 672266 (2.56 MB)
# Trainable params: 672266 (2.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 218s 578ms/step - loss: 4.8691 - accuracy: 0.3047
# Epoch 2/2
# 375/375 [==============================] - 210s 561ms/step - loss: 1.5942 - accuracy: 0.4401
# Test loss: 1.584790825843811
# Test accuracy: 0.4436666667461395
# (48000,)
# (12000,)
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_212 (Dense)           (None, 32, 32, 64)        256
#
#  dense_213 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_214 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_215 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_216 (Dense)           (None, 32, 32, 64)        4160
#
#  flatten_27 (Flatten)        (None, 65536)             0
#
#  dropout_27 (Dropout)        (None, 65536)             0
#
#  dense_217 (Dense)           (None, 10)                655370
#
# =================================================================
# Total params: 672266 (2.56 MB)
# Trainable params: 672266 (2.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 216s 573ms/step - loss: 4.6607 - accuracy: 0.2965
# Epoch 2/2
# 375/375 [==============================] - 217s 578ms/step - loss: 1.6039 - accuracy: 0.4342
# Test loss: 1.5736664533615112
# Test accuracy: 0.45116665959358215
# (48000,)
# (12000,)
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_218 (Dense)           (None, 32, 32, 64)        256
#
#  dense_219 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_220 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_221 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_222 (Dense)           (None, 32, 32, 64)        4160
#
#  flatten_28 (Flatten)        (None, 65536)             0
#
#  dropout_28 (Dropout)        (None, 65536)             0
#
#  dense_223 (Dense)           (None, 10)                655370
#
# =================================================================
# Total params: 672266 (2.56 MB)
# Trainable params: 672266 (2.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 221s 588ms/step - loss: 4.2040 - accuracy: 0.3010
# Epoch 2/2
# 375/375 [==============================] - 217s 579ms/step - loss: 1.6065 - accuracy: 0.4386
# Test loss: 1.5661612749099731
# Test accuracy: 0.4482499957084656
# (48000,)
# (12000,)
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_224 (Dense)           (None, 32, 32, 64)        256
#
#  dense_225 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_226 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_227 (Dense)           (None, 32, 32, 64)        4160
#
#  dense_228 (Dense)           (None, 32, 32, 64)        4160
#
#  flatten_29 (Flatten)        (None, 65536)             0
#
#  dropout_29 (Dropout)        (None, 65536)             0
#
#  dense_229 (Dense)           (None, 10)                655370
#
# =================================================================
# Total params: 672266 (2.56 MB)
# Trainable params: 672266 (2.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/2
# 375/375 [==============================] - 218s 577ms/step - loss: 6.3068 - accuracy: 0.2885
# Epoch 2/2
# 375/375 [==============================] - 212s 565ms/step - loss: 1.6184 - accuracy: 0.4325
# Test loss: 1.5941661596298218
# Test accuracy: 0.4465833306312561
# [0.44350001215934753, 0.4436666667461395, 0.45116665959358215, 0.4482499957084656, 0.4465833306312561]
